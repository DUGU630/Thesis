# %% [markdown]
# ## Import and Plot the Network

# %%
import spatial_agg as sa
import gurobipy as gp
from gurobipy import GRB
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
lines_df, nodes_df, wind_df, solar_df = sa.import_data()
sa.plot_network(lines_df, nodes_df);

# %% [markdown]
# ## Test of Spatial Agg functions

# %%
TimeSeriesList = [solar_df, wind_df]
TimeHorizon = 24
CF = sa.create_capacity_factor_array(nodes_df, TimeSeriesList, TimeHorizon)
N_prime = 10
lambdas = [1,1,1]
N, G, T = CF.shape;
# Out:
# Number of nodes: 17
# Number of time series features per node: 2
# Time horizon: 24

# %%
def correlation_features(CF):
    N, G, T = CF.shape
    TS_corr = np.zeros((N, N, G, G, T))

    for g in range(G):
        for h in range(G):
            if h != g:
                for n in range(N):
                    for m in range(N):
                        if m != n:
                            CF_n_g = CF[n, g, :]
                            CF_m_h = CF[m, h, :]
                            mean_n_g = np.mean(CF_n_g)
                            mean_m_h = np.mean(CF_m_h)
                            TS_corr[n, m, g, h, :] = (CF_n_g - mean_n_g) * (CF_m_h - mean_m_h)
    return TS_corr

# %%
import numpy as np
import pandas as pd

def create_capacity_factor_array(nodes_df, TimeSeriesList, TimeHorizon):
    N = nodes_df.shape[0]
    T = TimeHorizon
    G = len(TimeSeriesList)
    CF = np.zeros((N, G, T))

    for g in range(G):
        for n in range(N):
            for t in range(T):
                CF[n, g, t] = TimeSeriesList[g].iloc[t, n]

    print(f"Number of nodes: {N}")
    print(f"Number of time series features per node: {G}")
    print(f"Time horizon: {T}")

    return CF


def correlation_features(CF):
    N, G, T = CF.shape
    TS_corr = np.zeros((N, N, G, G, T))

    for g in range(G):
        for h in range(G):
            if h != g:
                for n in range(N):
                    for m in range(N):
                        if m != n:
                            CF_n_g = CF[n, g, :]
                            CF_m_h = CF[m, h, :]
                            mean_n_g = np.mean(CF_n_g)
                            mean_m_h = np.mean(CF_m_h)
                            TS_corr[n, m, g, h, :] = (CF_n_g - mean_n_g) * (CF_m_h - mean_m_h)
    return TS_corr
    


# Assuming the functions correlation_features and create_capacity_factor_array are defined as provided

# Example usage:

# Step 1: Create the Capacity Factor Array
nodes_df = pd.DataFrame({
    'node_num': [0, 1, 2],
    'State': ['MA', 'MA', 'MA'],
    'Lat': [42.642711, 42.479477, 42.331960],
    'Lon': [-70.865107, -71.396507, -71.020173],
    'Offshore_wind_allowed': [1, 1, 1],
    'ISONE_zone': ['MA', 'MA', 'MA']
})

# Example TimeSeriesList with dummy data
TimeSeriesList = [
    pd.DataFrame(np.random.rand(24, 3)),  # Generator 1 time series
    pd.DataFrame(np.random.rand(24, 3))   # Generator 2 time series
]

TimeHorizon = 24

CF = create_capacity_factor_array(nodes_df, TimeSeriesList, TimeHorizon)

# Step 2: Calculate Correlation Features
TS_corr = correlation_features(CF)

# Step 3: Access Node Features
def get_node_features(node_index, CF, TS_corr, nodes_df):
    node_features = {}
    
    # Time series per generator at that node
    node_features['time_series'] = CF[node_index, :, :]
    
    # Position of the node
    node_features['position'] = (nodes_df.loc[node_index, 'Lat'], nodes_df.loc[node_index, 'Lon'])
    
    # Correlation time series between the generator at that node and any other generator at any other node
    N, G, T = CF.shape
    correlation_time_series = {}
    for g in range(G):
        for h in range(G):
            if h != g:
                for m in range(N):
                    if m != node_index:
                        correlation_time_series[(g, h, m)] = TS_corr[node_index, m, g, h, :]
    
    node_features['correlation_time_series'] = correlation_time_series
    
    return node_features

# Example: Get features for node 0
node_index = 0
node_features = get_node_features(node_index, CF, TS_corr, nodes_df)

print("Node Features:")
print("Time Series per Generator at Node:", node_features['time_series'])
print("Position of Node:", node_features['position'])
print("Correlation Time Series:", node_features['correlation_time_series'])

# %%
def corr_coeff(CF, N, G, T):
    corr_coeff = np.zeros((N, N, G, G))
    for g in range(G):
        for h in range(G):
            if h != g:
                for n in range(N):
                    for m in range(N):
                        if m != n:
                            CF_n_g = CF[n, g, :]
                            CF_m_h = CF[m, h, :]
                            mean_n_g = np.mean(CF_n_g)
                            mean_m_h = np.mean(CF_m_h)
                            numerator = np.sum((CF_n_g - mean_n_g) * (CF_m_h - mean_m_h))
                            denominator = np.sqrt(np.sum((CF_n_g - mean_n_g)**2) * np.sum((CF_m_h - mean_m_h)**2))
                            corr_coeff[n, m, g, h] = numerator / denominator
    return corr_coeff

# %%
# Initialize the model
model = gp.Model("node_aggregation")
model.Params.NonConvex = 2

# Define variables
alpha = model.addVars(N, N_prime, vtype=GRB.BINARY, name="alpha")
C_agg = model.addVars(
    N_prime, G, T, vtype=GRB.CONTINUOUS, name="C_agg", lb=0)
coords_agg = model.addVars(
    N_prime, 2, vtype=GRB.CONTINUOUS, name="coords_agg", lb=0)

# Objective components

### NRMSE
# Variable and Constraint to handle the square root in NRMSE_av
sqrt_NRMSE_terms = model.addVars(N, G, vtype=GRB.CONTINUOUS, name="sqrt_NRMSE_terms")
for n in range(N):
    for g in range(G):
        for n_prime in range(N_prime):
            squared_error = (1 / T) * sum((CF[n, g, t] - C_agg[n_prime, g, t])**2 for t in range(T))
            model.addConstr(sqrt_NRMSE_terms[n, g] * sqrt_NRMSE_terms[n, g] >= squared_error)
            
# Now define NRMSE_av using the auxiliary variable sqrt_NRMSE_terms
NRMSE_av = sum(sum(alpha[n, n_prime] * (1 / G) * sqrt_NRMSE_terms[n, g] / (CF[n, g, :].max() - CF[n, g, :].min())
                for g in range(G)) for n_prime in range(N_prime) for n in range(N))

### Spatial distance error
# Define auxiliary variables for spatial distance
dist = model.addVars(N, N_prime, vtype=GRB.CONTINUOUS, name="dist")

# Constraints to approximate the Euclidean distance
for n in range(N):
    for n_prime in range(N_prime):
        # Calculate the squared Euclidean distance between points
        squared_distance = (nodes_df.iloc[n]['Lat'] - coords_agg[n_prime, 0])**2 + \
                           (nodes_df.iloc[n]['Lon'] - coords_agg[n_prime, 1])**2

        # Constrain dist[n, n_prime] to be at least the square root of the squared distance
        model.addConstr(dist[n, n_prime] * dist[n, n_prime] >= squared_distance)

# Define the spatial distance error objective term using the auxiliary variable
spatial_distance_error = sum(sum(alpha[n, n_prime] * dist[n, n_prime] for n_prime in range(N_prime)) for n in range(N))

# Set objective
model.setObjective(lambdas[0] * NRMSE_av + lambdas[1] * spatial_distance_error, GRB.MINIMIZE)

# Add constraints
model.addConstrs((gp.quicksum(alpha[n, n_prime] for n_prime in range(
    N_prime)) == 1 for n in range(N)), "assignment")

# Optimize the model
model.optimize()

C_agg.x, alpha.x, coords_agg.x
# Out:
# Set parameter NonConvex to value 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 17 rows, 874 columns and 170 nonzeros
# Model fingerprint: 0xfeb48fbb
# Model has 510 quadratic objective terms
# Model has 510 quadratic constraints
# Variable types: 704 continuous, 170 integer (170 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    
#  49061 36189    1.13884  106   36   10.18740    0.00000   100%   457 63836s
#  49729 36775    5.88770  125   18   10.18740    0.00000   100%   459 63944s
#  50495 37779    2.09925   84   39   10.18740    0.00000   100%   458 64027s
#  51769 38302    1.58309   65   36   10.18740    0.00000   100%   454 64103s
#  52604 38806    3.64745   99   39   10.18740    0.00000   100%   452 64183s
#  53144 39247    9.50913  134   18   10.18740    0.00000   100%   454 64260s
#  53717 40125    4.70399   76   36   10.18740    0.00000   100%   457 64334s
#  54815 40601    1.57624  102   33   10.18740    0.00000   100%   456 64413s
#  55499 41188    6.04316  110   15   10.18740    0.00000   100%   458 64997s
#  56252 41702    0.05354   55   45   10.18740    0.00000   100%   455 65091s
#  56848 42268    1.50395   72   39   10.18740    0.00000   100%   458 65175s
#  57468 42632    4.40339  117   27   10.18740    0.00000   100%   462 65258s
#  57934 43436    6.44660   44   33   10.18740    0.00000   100%   467 65371s

# %%
# Initialize the model
model = gp.Model("node_aggregation")
model.Params.NonConvex = 2

# Define variables
alpha = model.addVars(N, N_prime, vtype=GRB.BINARY, name="alpha")
C_agg = model.addVars(
    N_prime, G, T, vtype=GRB.CONTINUOUS, name="C_agg", lb=0)
coords_agg = model.addVars(
    N_prime, 2, vtype=GRB.CONTINUOUS, name="coords_agg", lb=0)

# Objective components

### NRMSE
# Variable and Constraint to handle the square root in NRMSE_av
sqrt_NRMSE_terms = model.addVars(N, G, vtype=GRB.CONTINUOUS, name="sqrt_NRMSE_terms")
for n in range(N):
    for g in range(G):
        for n_prime in range(N_prime):
            squared_error = (1 / T) * sum((CF[n, g, t] - C_agg[n_prime, g, t])**2 for t in range(T))
            model.addConstr(sqrt_NRMSE_terms[n, g] * sqrt_NRMSE_terms[n, g] >= squared_error)
            
# Now define NRMSE_av using the auxiliary variable sqrt_NRMSE_terms
NRMSE_av = sum(sum(alpha[n, n_prime] * (1 / G) * sqrt_NRMSE_terms[n, g] / (CF[n, g, :].max() - CF[n, g, :].min())
                for g in range(G)) for n_prime in range(N_prime) for n in range(N))

### Correlation Error Term with Approximation
# Auxiliary variables for the correlation terms
numerator_terms = model.addVars(N, N, G, G, vtype=GRB.CONTINUOUS, name="numerator_terms")
denominator_terms = model.addVars(N, N, G, G, vtype=GRB.CONTINUOUS, name="denominator_terms")
approx_sqrt_denom = model.addVars(N, N, G, G, vtype=GRB.CONTINUOUS, name="approx_sqrt_denom")
abs_diff_corr = model.addVars(N, N, G, G, vtype=GRB.CONTINUOUS, name="abs_diff_corr")

for n in range(N):
    for m in range(N):
        if m != n:
            for g in range(G):
                for h in range(G):
                    if h != g:
                        # Mean values precomputed for correlation calculation
                        CF_n_g = CF[n, g, :]
                        CF_m_h = CF[m, h, :]
                        mean_n_g = np.mean(CF_n_g)
                        mean_m_h = np.mean(CF_m_h)

                        # Define numerator for correlation coefficient
                        numerator_expr = sum((CF_n_g[t] - mean_n_g) * (CF_m_h[t] - mean_m_h) for t in range(T))
                        model.addConstr(numerator_terms[n, m, g, h] == numerator_expr)

                        # Define denominator for correlation coefficient using auxiliary variables
                        sum_sq_n = sum((CF_n_g[t] - mean_n_g) ** 2 for t in range(T))
                        sum_sq_m = sum((CF_m_h[t] - mean_m_h) ** 2 for t in range(T))

                        # Ensure denominator_terms approximates sum of squares
                        model.addConstr(denominator_terms[n, m, g, h] == sum_sq_n * sum_sq_m)
                        model.addConstr(approx_sqrt_denom[n, m, g, h] * approx_sqrt_denom[n, m, g, h] >= denominator_terms[n, m, g, h])

                        # Absolute difference in correlation coefficients
                        corr_CF = numerator_terms[n, m, g, h] / (approx_sqrt_denom[n, m, g, h] + 1e-5)  # Small constant to avoid div by zero
                        corr_C_agg = sum((C_agg[n_prime, g, t] - mean_n_g) * (C_agg[m_prime, h, t] - mean_m_h) for t in range(T)) / (approx_sqrt_denom[n, m, g, h] + 1e-5)
                        model.addConstr(abs_diff_corr[n, m, g, h] >= corr_CF - corr_C_agg)
                        model.addConstr(abs_diff_corr[n, m, g, h] >= corr_C_agg - corr_CF)

corr_error = sum(sum(sum(sum(alpha[n, n_prime] * alpha[m, m_prime] / (G*(G-1)) * abs_diff_corr[n, m, g, h]
                            for h in range(G) if h != g) for g in range(G)) for m_prime in range(N_prime)) for n_prime in range(N_prime))



# NRMSE_av = sum(sum(alpha[n, n_prime] * (1 / G) * sum((1/T * sum((CF[n, g, t] - C_agg[n_prime, g, t])**2 for t in range(
#     T)))**0.5 / (CF[n, g, :].max() - CF[n, g, :].min()) for g in range(G)) for n_prime in range(N_prime)) for n in range(N))

# Set objective
model.setObjective(lambdas[0] * NRMSE_av + lambdas[1] * corr_error, GRB.MINIMIZE)

# Add constraints
model.addConstrs((gp.quicksum(alpha[n, n_prime] for n_prime in range(
    N_prime)) == 1 for n in range(N)), "assignment")
# model.addConstrs((C_agg[n_prime, :, :] * gp.quicksum(alpha[n, n_prime] for n in range(N)) == gp.quicksum(alpha[n, n_prime] * CF[n, :, :] for n in range(
#     N)) for n_prime in range(N_prime)), "capacity_factor")

# Optimize the model
model.optimize()

C_agg.x, alpha.x, coords_agg.x
# Out:
# Set parameter NonConvex to value 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File src\\gurobipy\\var.pxi:297, in gurobipy.Var.__truediv__()
#
# TypeError: float() argument must be a string or a real number, not 'gurobipy.LinExpr'
#
# During handling of the above exception, another exception occurred:
#
# GurobiError                               Traceback (most recent call last)
# Cell In[28], line 59
#      56 model.addConstr(approx_sqrt_denom[n, m, g, h] * approx_sqrt_denom[n, m, g, h] >= denominator_terms[n, m, g, h])
#      58 # Absolute difference in correlation coefficients
# ---> 59 corr_CF = numerator_terms[n, m, g, h] / (approx_sqrt_denom[n, m, g, h] + 1e-5)  # Small constant to avoid div by zero
#      60 corr_C_agg = sum((C_agg[n_prime, g, t] - mean_n_g) * (C_agg[m_prime, h, t] - mean_m_h) for t in range(T)) / (approx_sqrt_denom[n, m, g, h] + 1e-5)
#      61 model.addConstr(abs_diff_corr[n, m, g, h] >= corr_CF - corr_C_agg)
#
# File src\\gurobipy\\var.pxi:299, in gurobipy.Var.__truediv__()
#
# GurobiError: Divisor must be a constant

# %%
# Initialize the model
model = gp.Model("node_aggregation")
model.Params.NonConvex = 2

# Define variables
alpha = model.addVars(N, N_prime, vtype=GRB.BINARY, name="alpha")
C_agg = model.addVars(
    N_prime, G, T, vtype=GRB.CONTINUOUS, name="C_agg", lb=0)
coords_agg = model.addVars(
    N_prime, 2, vtype=GRB.CONTINUOUS, name="coords_agg", lb=0)

# Objective components
# Additional step: Define auxiliary variables for square root terms
sqrt_NRMSE_terms = model.addVars(N, G, vtype=GRB.CONTINUOUS, name="sqrt_NRMSE_terms")

# Constraints to handle the square root in NRMSE_av
for n in range(N):
    for g in range(G):
        for n_prime in range(N_prime):
            # Define the squared error term
            squared_error = (1 / T) * sum((CF[n, g, t] - C_agg[n_prime, g, t])**2 for t in range(T))
            
            # Constrain the auxiliary variable to represent the square root of squared_error
            model.addConstr(sqrt_NRMSE_terms[n, g] * sqrt_NRMSE_terms[n, g] >= squared_error)
            
# Now define NRMSE_av using the auxiliary variable sqrt_NRMSE_terms
NRMSE_av = sum(sum(alpha[n, n_prime] * (1 / G) * sqrt_NRMSE_terms[n, g] / (CF[n, g, :].max() - CF[n, g, :].min())
                for g in range(G)) for n_prime in range(N_prime) for n in range(N))


NRMSE_av = sum(sum(alpha[n, n_prime] * (1 / G) * sum((1/T * sum((CF[n, g, t] - C_agg[n_prime, g, t])**2 for t in range(
    T)))**0.5 / (CF[n, g, :].max() - CF[n, g, :].min()) for g in range(G)) for n_prime in range(N_prime)) for n in range(N))

corr_error = sum(sum(sum(sum(alpha[n, n_prime] * alpha[m, m_prime] / (G*(G-1)) * sum(sum(gp.abs_(corr_coeff(CF)[n, m, g, h] - corr_coeff(C_agg)[n_prime, m_prime, g, h])
                    for h in range(G) if h != g) for g in range(G)) for m_prime in range(N_prime)) for n_prime in range(N_prime)) for m in range(N) if m != n) for n in range(N))

spatial_distance_error = sum(sum(alpha[n, n_prime] * ((nodes_df.iloc[n]['Lat'] - coords_agg[n_prime, 0])**2 + (
    nodes_df.iloc[n]['Lon'] - coords_agg[n_prime, 1])**2)**0.5 for n_prime in range(N_prime)) for n in range(N))

# Set objective
model.setObjective(lambdas[0] * NRMSE_av + lambdas[3] * corr_error +
                    lambdas[2] * spatial_distance_error, GRB.MINIMIZE)

# Add constraints
model.addConstrs((gp.quicksum(alpha[n, n_prime] for n_prime in range(
    N_prime)) == 1 for n in range(N)), "assignment")
model.addConstrs((C_agg[n_prime, :, :] * gp.quicksum(alpha[n, n_prime] for n in range(N)) == gp.quicksum(alpha[n, n_prime] * CF[n, :, :] for n in range(
    N)) for n_prime in range(N_prime)), "capacity_factor")

# Optimize the model
model.optimize()

return CF.x, alpha.x, coords_agg.x

# %%
N_prime = 10
lambdas = [1, 1, 1]
N = CF.shape[0]
G = CF.shape[1]
T = CF.shape[2]
alpha = np.random.rand(N, N_prime)
C_agg = np.random.rand(N_prime, G, T)

NRMSE_av = sum(sum(alpha[n, n_prime] * (1 / G) * sum(np.sqrt(1/T * sum((CF[n, g, t] - C_agg[n_prime, g, t])**2 for t in range(T))) / (CF[n, g, :].max() - CF[n, g, :].min()) for g in range(G)) for n_prime in range(N_prime)) for n in range(N))

# %%
N_prime = 10
lambda1, lambda2, lambda3 = 1, 1, 1
CF_result, alpha_result, coords_result = sa.aggregate_nodes(CF, nodes_df, N_prime)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-06
# Set parameter NonConvex to value 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 N_prime = 10
#       2 lambda1, lambda2, lambda3 = 1, 1, 1
# ----> 3 CF_result, alpha_result, coords_result = sa.aggregate_nodes(CF, nodes_df, N_prime)
#
# File c:\Users\g630d\Documents\00_Cours\2024-2025_MIT\00 Thesis\Dev\spatial_agg.py:122, in aggregate_nodes(CF, nodes_df, N_prime, lambdas)
#     118 coords_agg = model.addVars(
#     119     N_prime, 2, vtype=GRB.CONTINUOUS, name="coords_agg", lb=0)
#     121 # Objective components
# --> 122 NRMSE_av = sum(sum(alpha[n, n_prime] * (1 / G) * sum((1/T * sum((CF[n, g, t] - C_agg[n_prime, g, t])**2 for t in range(
#     123     T)))**0.5 / (CF[n, g, :].max() - CF[n, g, :].min()) for g in range(G)) for n_prime in range(N_prime)) for n in range(N))
#     125 corr_error = sum(sum(sum(sum(alpha[n, n_prime] * alpha[m, m_prime] / (G*(G-1)) * sum(sum(gp.abs_(corr_coeff(CF)[n, m, g, h] - corr_coeff(C_agg)[n_prime, m_prime, g, h])
#     126                  for h in range(G) if h != g) for g in range(G)) for m_prime in range(N_prime)) for n_prime in range(N_prime)) for m in range(N) if m != n) for n in range(N))
#     128 spatial_distance_error = sum(sum(alpha[n, n_prime] * ((nodes_df.iloc[n]['Lat'] - coords_agg[n_prime, 0])**2 + (
#     129     nodes_df.iloc[n]['Lon'] - coords_agg[n_prime, 1])**2)**0.5 for n_prime in range(N_prime)) for n in range(N))
#
# File c:\Users\g630d\Documents\00_Cours\2024-2025_MIT\00 Thesis\Dev\spatial_agg.py:122, in <genexpr>(.0)
#     118 coords_agg = model.addVars(
#     119     N_prime, 2, vtype=GRB.CONTINUOUS, name="coords_agg", lb=0)
#     121 # Objective components
# --> 122 NRMSE_av = sum(sum(alpha[n, n_prime] * (1 / G) * sum((1/T * sum((CF[n, g, t] - C_agg[n_prime, g, t])**2 for t in range(
#     123     T)))**0.5 / (CF[n, g, :].max() - CF[n, g, :].min()) for g in range(G)) for n_prime in range(N_prime)) for n in range(N))
#     125 corr_error = sum(sum(sum(sum(alpha[n, n_prime] * alpha[m, m_prime] / (G*(G-1)) * sum(sum(gp.abs_(corr_coeff(CF)[n, m, g, h] - corr_coeff(C_agg)[n_prime, m_prime, g, h])
#     126                  for h in range(G) if h != g) for g in range(G)) for m_prime in range(N_prime)) for n_prime in range(N_prime)) for m in range(N) if m != n) for n in range(N))
#     128 spatial_distance_error = sum(sum(alpha[n, n_prime] * ((nodes_df.iloc[n]['Lat'] - coords_agg[n_prime, 0])**2 + (
#     129     nodes_df.iloc[n]['Lon'] - coords_agg[n_prime, 1])**2)**0.5 for n_prime in range(N_prime)) for n in range(N))
#
# File c:\Users\g630d\Documents\00_Cours\2024-2025_MIT\00 Thesis\Dev\spatial_agg.py:122, in <genexpr>(.0)
#     118 coords_agg = model.addVars(
#     119     N_prime, 2, vtype=GRB.CONTINUOUS, name="coords_agg", lb=0)
#     121 # Objective components
# --> 122 NRMSE_av = sum(sum(alpha[n, n_prime] * (1 / G) * sum((1/T * sum((CF[n, g, t] - C_agg[n_prime, g, t])**2 for t in range(
#     123     T)))**0.5 / (CF[n, g, :].max() - CF[n, g, :].min()) for g in range(G)) for n_prime in range(N_prime)) for n in range(N))
#     125 corr_error = sum(sum(sum(sum(alpha[n, n_prime] * alpha[m, m_prime] / (G*(G-1)) * sum(sum(gp.abs_(corr_coeff(CF)[n, m, g, h] - corr_coeff(C_agg)[n_prime, m_prime, g, h])
#     126                  for h in range(G) if h != g) for g in range(G)) for m_prime in range(N_prime)) for n_prime in range(N_prime)) for m in range(N) if m != n) for n in range(N))
#     128 spatial_distance_error = sum(sum(alpha[n, n_prime] * ((nodes_df.iloc[n]['Lat'] - coords_agg[n_prime, 0])**2 + (
#     129     nodes_df.iloc[n]['Lon'] - coords_agg[n_prime, 1])**2)**0.5 for n_prime in range(N_prime)) for n in range(N))
#
# File c:\Users\g630d\Documents\00_Cours\2024-2025_MIT\00 Thesis\Dev\spatial_agg.py:122, in <genexpr>(.0)
#     118 coords_agg = model.addVars(
#     119     N_prime, 2, vtype=GRB.CONTINUOUS, name="coords_agg", lb=0)
#     121 # Objective components
# --> 122 NRMSE_av = sum(sum(alpha[n, n_prime] * (1 / G) * sum((1/T * sum((CF[n, g, t] - C_agg[n_prime, g, t])**2 for t in range(
#     123     T)))**0.5 / (CF[n, g, :].max() - CF[n, g, :].min()) for g in range(G)) for n_prime in range(N_prime)) for n in range(N))
#     125 corr_error = sum(sum(sum(sum(alpha[n, n_prime] * alpha[m, m_prime] / (G*(G-1)) * sum(sum(gp.abs_(corr_coeff(CF)[n, m, g, h] - corr_coeff(C_agg)[n_prime, m_prime, g, h])
#     126                  for h in range(G) if h != g) for g in range(G)) for m_prime in range(N_prime)) for n_prime in range(N_prime)) for m in range(N) if m != n) for n in range(N))
#     128 spatial_distance_error = sum(sum(alpha[n, n_prime] * ((nodes_df.iloc[n]['Lat'] - coords_agg[n_prime, 0])**2 + (
#     129     nodes_df.iloc[n]['Lon'] - coords_agg[n_prime, 1])**2)**0.5 for n_prime in range(N_prime)) for n in range(N))
#
# TypeError: unsupported operand type(s) for ** or pow(): 'gurobipy.QuadExpr' and 'float'

# %%
corr_coeff = np.zeros((N, N, G, G))
corr_coeff1 = np.zeros((N, N, G, G))
corr_coeff2 = np.zeros((N, N, G, G))

for g in range(G):
    for h in range(G):
        if h != g:
            CF_g = CF[:, g, :]
            CF_h = CF[:, h, :]
            corr_matrix = np.corrcoef(CF_g, CF_h, rowvar=True)
            corr_coeff2[:, :, g, h] = corr_matrix[:N, N:]

for g in range(G):
    for h in range(G):
        if h != g:
            for n in range(N):
                for m in range(N):
                    if m != n:
                        CF_n_g = CF[n, g, :]
                        CF_m_h = CF[m, h, :]
                        mean_n_g = np.mean(CF_n_g)
                        mean_m_h = np.mean(CF_m_h)
                        numerator = np.sum((CF_n_g - mean_n_g) * (CF_m_h - mean_m_h))
                        denominator = np.sqrt(np.sum((CF_n_g - mean_n_g)**2) * np.sum((CF_m_h - mean_m_h)**2))
                        corr_coeff[n, m, g, h] = numerator / denominator
                        corr_coeff1[n, m, g, h] = np.corrcoef(CF_n_g, CF_m_h)[0, 1]
                        if not np.isclose(corr_coeff[n, m, g, h], corr_coeff1[n, m, g, h], atol=1e-8):
                            print(f"Difference at g={g}, h={h}, n={n}, m={m}: corr_coeff={corr_coeff[n, m, g, h]}, corr_coeff1={corr_coeff1[n, m, g, h]}")
                        if not np.isclose(corr_coeff2[n, m, g, h], corr_coeff[n, m, g, h], atol=1e-15):
                            print(f"Difference at g={g}, h={h}, n={n}, m={m}: corr_coeff2={corr_coeff2[n, m, g, h]}, corr_coeff={corr_coeff[n, m, g, h]}")
        elif g == h:
            for n in range(N):
                for m in range(N):
                    if m != n:
                        print (f"n={n}, m={m}, g={g}, h={h}: corr_coeff={corr_coeff[n, m, g, h]}, corr_coeff1={corr_coeff1[n, m, g, h]}, corr_coeff2={corr_coeff2[n, m, g, h]}")
                        if not np.isclose(corr_coeff2[n, m, g, h], corr_coeff[n, m, g, h], atol=1e-15):
                            print(f"Difference at g={g}, h={h}, n={n}, m={m}: corr_coeff2={corr_coeff2[n, m, g, h]}, corr_coeff={corr_coeff[n, m, g, h]}")
                    else:
                        print (f"n={n}, m={m}, g={g}, h={h}: corr_coeff={corr_coeff[n, m, g, h]}, corr_coeff1={corr_coeff1[n, m, g, h]}, corr_coeff2={corr_coeff2[n, m, g, h]}")
                        if not np.isclose(corr_coeff2[n, m, g, h], corr_coeff[n, m, g, h], atol=1e-15):
                            print(f"Difference at g={g}, h={h}, n={n}, m={m}: corr_coeff2={corr_coeff2[n, m, g, h]}, corr_coeff={corr_coeff[n, m, g, h]}")
# Out:
# n=0, m=0, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=0, h=0, n=0, m=0: corr_coeff2=1.0, corr_coeff=0.0
# n=0, m=1, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9904004755094789
# Difference at g=0, h=0, n=0, m=1: corr_coeff2=0.9904004755094789, corr_coeff=0.0
# n=0, m=2, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9830625979292967
# Difference at g=0, h=0, n=0, m=2: corr_coeff2=0.9830625979292967, corr_coeff=0.0
# n=0, m=3, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9511467652280147
# Difference at g=0, h=0, n=0, m=3: corr_coeff2=0.9511467652280147, corr_coeff=0.0
# n=0, m=4, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9381865853547733
# Difference at g=0, h=0, n=0, m=4: corr_coeff2=0.9381865853547733, corr_coeff=0.0
# n=0, m=5, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8776534427980515
# Difference at g=0, h=0, n=0, m=5: corr_coeff2=0.8776534427980515, corr_coeff=0.0
# n=0, m=6, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8659999662858809
# Difference at g=0, h=0, n=0, m=6: corr_coeff2=0.8659999662858809, corr_coeff=0.0
# n=0, m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.866719128071629
# Difference at g=0, h=0, n=0, m=7: corr_coeff2=0.866719128071629, corr_coeff=0.0
# n=0, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9232156392784633
# Difference at g=0, h=0, n=0, m=8: corr_coeff2=0.9232156392784633, corr_coeff=0.0
# n=0, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7079754575427764
# Difference at g=0, h=0, n=0, m=9: corr_coeff2=0.7079754575427764, corr_coeff=0.0
# n=0, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9185492107077885
# Difference at g=0, h=0, n=0, m=10: corr_coeff2=0.9185492107077885, corr_coeff=0.0
# n=0, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8549707870540497
# Difference at g=0, h=0, n=0, m=11: corr_coeff2=0.8549707870540497, corr_coeff=0.0
# n=0, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.905438398987375
# Difference at g=0, h=0, n=0, m=12: corr_coeff2=0.905438398987375, corr_coeff=0.0
# n=0, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8130378173473594
# Difference at g=0, h=0, n=0, m=13: corr_coeff2=0.8130378173473594, corr_coeff=0.0
# n=0, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8513580355083243
# Difference at g=0, h=0, n=0, m=14: corr_coeff2=0.8513580355083243, corr_coeff=0.0
# n=0, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8410306523179275
# Difference at g=0, h=0, n=0, m=15: corr_coeff2=0.8410306523179275, corr_coeff=0.0
# n=0, m=16, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8322068186894682
# Difference at g=0, h=0, n=0, m=16: corr_coeff2=0.8322068186894682, corr_coeff=0.0
# n=1, m=0, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9904004755094789
# Difference at g=0, h=0, n=1, m=0: corr_coeff2=0.9904004755094789, corr_coeff=0.0
# n=1, m=1, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=0, h=0, n=1, m=1: corr_coeff2=1.0, corr_coeff=0.0
# n=1, m=2, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9609730703392965
# Difference at g=0, h=0, n=1, m=2: corr_coeff2=0.9609730703392965, corr_coeff=0.0
# n=1, m=3, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9302764357567344
# Difference at g=0, h=0, n=1, m=3: corr_coeff2=0.9302764357567344, corr_coeff=0.0
# n=1, m=4, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9108064615438901
# Difference at g=0, h=0, n=1, m=4: corr_coeff2=0.9108064615438901, corr_coeff=0.0
# n=1, m=5, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8751750345551418
# Difference at g=0, h=0, n=1, m=5: corr_coeff2=0.8751750345551418, corr_coeff=0.0
# n=1, m=6, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8661162774140966
# Difference at g=0, h=0, n=1, m=6: corr_coeff2=0.8661162774140966, corr_coeff=0.0
# n=1, m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.875573195635244
# Difference at g=0, h=0, n=1, m=7: corr_coeff2=0.875573195635244, corr_coeff=0.0
# n=1, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9149434662242366
# Difference at g=0, h=0, n=1, m=8: corr_coeff2=0.9149434662242366, corr_coeff=0.0
# n=1, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7397284151364037
# Difference at g=0, h=0, n=1, m=9: corr_coeff2=0.7397284151364037, corr_coeff=0.0
# n=1, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9168614672914073
# Difference at g=0, h=0, n=1, m=10: corr_coeff2=0.9168614672914073, corr_coeff=0.0
# n=1, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8681057860969704
# Difference at g=0, h=0, n=1, m=11: corr_coeff2=0.8681057860969704, corr_coeff=0.0
# n=1, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8758578730468864
# Difference at g=0, h=0, n=1, m=12: corr_coeff2=0.8758578730468864, corr_coeff=0.0
# n=1, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7956173027478828
# Difference at g=0, h=0, n=1, m=13: corr_coeff2=0.7956173027478828, corr_coeff=0.0
# n=1, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8261500788732833
# Difference at g=0, h=0, n=1, m=14: corr_coeff2=0.8261500788732833, corr_coeff=0.0
# n=1, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8187196427335749
# Difference at g=0, h=0, n=1, m=15: corr_coeff2=0.8187196427335749, corr_coeff=0.0
# n=1, m=16, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8100105621622552
# Difference at g=0, h=0, n=1, m=16: corr_coeff2=0.8100105621622552, corr_coeff=0.0
# n=2, m=0, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9830625979292967
# Difference at g=0, h=0, n=2, m=0: corr_coeff2=0.9830625979292967, corr_coeff=0.0
# n=2, m=1, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9609730703392965
# Difference at g=0, h=0, n=2, m=1: corr_coeff2=0.9609730703392965, corr_coeff=0.0
# n=2, m=2, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9999999999999998
# Difference at g=0, h=0, n=2, m=2: corr_coeff2=0.9999999999999998, corr_coeff=0.0
# n=2, m=3, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9656185783754662
# Difference at g=0, h=0, n=2, m=3: corr_coeff2=0.9656185783754662, corr_coeff=0.0
# n=2, m=4, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.947662295731792
# Difference at g=0, h=0, n=2, m=4: corr_coeff2=0.947662295731792, corr_coeff=0.0
# n=2, m=5, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.879831740386682
# Difference at g=0, h=0, n=2, m=5: corr_coeff2=0.879831740386682, corr_coeff=0.0
# n=2, m=6, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8502770748170825
# Difference at g=0, h=0, n=2, m=6: corr_coeff2=0.8502770748170825, corr_coeff=0.0
# n=2, m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8421732648105078
# Difference at g=0, h=0, n=2, m=7: corr_coeff2=0.8421732648105078, corr_coeff=0.0
# n=2, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.909874289561796
# Difference at g=0, h=0, n=2, m=8: corr_coeff2=0.909874289561796, corr_coeff=0.0
# n=2, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6769817800752718
# Difference at g=0, h=0, n=2, m=9: corr_coeff2=0.6769817800752718, corr_coeff=0.0
# n=2, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9000240669147904
# Difference at g=0, h=0, n=2, m=10: corr_coeff2=0.9000240669147904, corr_coeff=0.0
# n=2, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8320378395179635
# Difference at g=0, h=0, n=2, m=11: corr_coeff2=0.8320378395179635, corr_coeff=0.0
# n=2, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.918555332366098
# Difference at g=0, h=0, n=2, m=12: corr_coeff2=0.918555332366098, corr_coeff=0.0
# n=2, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8137732038298511
# Difference at g=0, h=0, n=2, m=13: corr_coeff2=0.8137732038298511, corr_coeff=0.0
# n=2, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8548508258843968
# Difference at g=0, h=0, n=2, m=14: corr_coeff2=0.8548508258843968, corr_coeff=0.0
# n=2, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8421230465990155
# Difference at g=0, h=0, n=2, m=15: corr_coeff2=0.8421230465990155, corr_coeff=0.0
# n=2, m=16, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8470144082395814
# Difference at g=0, h=0, n=2, m=16: corr_coeff2=0.8470144082395814, corr_coeff=0.0
# n=3, m=0, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9511467652280147
# Difference at g=0, h=0, n=3, m=0: corr_coeff2=0.9511467652280147, corr_coeff=0.0
# n=3, m=1, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9302764357567342
# Difference at g=0, h=0, n=3, m=1: corr_coeff2=0.9302764357567342, corr_coeff=0.0
# n=3, m=2, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9656185783754663
# Difference at g=0, h=0, n=3, m=2: corr_coeff2=0.9656185783754663, corr_coeff=0.0
# n=3, m=3, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=0, h=0, n=3, m=3: corr_coeff2=1.0, corr_coeff=0.0
# n=3, m=4, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9402057338815615
# Difference at g=0, h=0, n=3, m=4: corr_coeff2=0.9402057338815615, corr_coeff=0.0
# n=3, m=5, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8836953182891087
# Difference at g=0, h=0, n=3, m=5: corr_coeff2=0.8836953182891087, corr_coeff=0.0
# n=3, m=6, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8455189709412181
# Difference at g=0, h=0, n=3, m=6: corr_coeff2=0.8455189709412181, corr_coeff=0.0
# n=3, m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8412435091549898
# Difference at g=0, h=0, n=3, m=7: corr_coeff2=0.8412435091549898, corr_coeff=0.0
# n=3, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9229875580851554
# Difference at g=0, h=0, n=3, m=8: corr_coeff2=0.9229875580851554, corr_coeff=0.0
# n=3, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6974489685904395
# Difference at g=0, h=0, n=3, m=9: corr_coeff2=0.6974489685904395, corr_coeff=0.0
# n=3, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.911697938860713
# Difference at g=0, h=0, n=3, m=10: corr_coeff2=0.911697938860713, corr_coeff=0.0
# n=3, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8585054014720543
# Difference at g=0, h=0, n=3, m=11: corr_coeff2=0.8585054014720543, corr_coeff=0.0
# n=3, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9428307893847977
# Difference at g=0, h=0, n=3, m=12: corr_coeff2=0.9428307893847977, corr_coeff=0.0
# n=3, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7924944294783054
# Difference at g=0, h=0, n=3, m=13: corr_coeff2=0.7924944294783054, corr_coeff=0.0
# n=3, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8671332316533976
# Difference at g=0, h=0, n=3, m=14: corr_coeff2=0.8671332316533976, corr_coeff=0.0
# n=3, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.
m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8139530232640904
# Difference at g=0, h=0, n=5, m=7: corr_coeff2=0.8139530232640904, corr_coeff=0.0
# n=5, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8521539517389077
# Difference at g=0, h=0, n=5, m=8: corr_coeff2=0.8521539517389077, corr_coeff=0.0
# n=5, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7753926416382189
# Difference at g=0, h=0, n=5, m=9: corr_coeff2=0.7753926416382189, corr_coeff=0.0
# n=5, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8458983504475717
# Difference at g=0, h=0, n=5, m=10: corr_coeff2=0.8458983504475717, corr_coeff=0.0
# n=5, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8367596943846349
# Difference at g=0, h=0, n=5, m=11: corr_coeff2=0.8367596943846349, corr_coeff=0.0
# n=5, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8497366640574356
# Difference at g=0, h=0, n=5, m=12: corr_coeff2=0.8497366640574356, corr_coeff=0.0
# n=5, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7809630253852381
# Difference at g=0, h=0, n=5, m=13: corr_coeff2=0.7809630253852381, corr_coeff=0.0
# n=5, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8232418371165429
# Difference at g=0, h=0, n=5, m=14: corr_coeff2=0.8232418371165429, corr_coeff=0.0
# n=5, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8639705226094745
# Difference at g=0, h=0, n=5, m=15: corr_coeff2=0.8639705226094745, corr_coeff=0.0
# n=5, m=16, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7885104470134595
# Difference at g=0, h=0, n=5, m=16: corr_coeff2=0.7885104470134595, corr_coeff=0.0
# n=6, m=0, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.865999966285881
# Difference at g=0, h=0, n=6, m=0: corr_coeff2=0.865999966285881, corr_coeff=0.0
# n=6, m=1, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8661162774140966
# Difference at g=0, h=0, n=6, m=1: corr_coeff2=0.8661162774140966, corr_coeff=0.0
# n=6, m=2, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8502770748170825
# Difference at g=0, h=0, n=6, m=2: corr_coeff2=0.8502770748170825, corr_coeff=0.0
# n=6, m=3, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8455189709412181
# Difference at g=0, h=0, n=6, m=3: corr_coeff2=0.8455189709412181, corr_coeff=0.0
# n=6, m=4, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8181493167606412
# Difference at g=0, h=0, n=6, m=4: corr_coeff2=0.8181493167606412, corr_coeff=0.0
# n=6, m=5, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9147430493788516
# Difference at g=0, h=0, n=6, m=5: corr_coeff2=0.9147430493788516, corr_coeff=0.0
# n=6, m=6, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=0, h=0, n=6, m=6: corr_coeff2=1.0, corr_coeff=0.0
# n=6, m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7897823486603947
# Difference at g=0, h=0, n=6, m=7: corr_coeff2=0.7897823486603947, corr_coeff=0.0
# n=6, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8457674554130286
# Difference at g=0, h=0, n=6, m=8: corr_coeff2=0.8457674554130286, corr_coeff=0.0
# n=6, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7602385506950997
# Difference at g=0, h=0, n=6, m=9: corr_coeff2=0.7602385506950997, corr_coeff=0.0
# n=6, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8701281004884583
# Difference at g=0, h=0, n=6, m=10: corr_coeff2=0.8701281004884583, corr_coeff=0.0
# n=6, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8362997242203086
# Difference at g=0, h=0, n=6, m=11: corr_coeff2=0.8362997242203086, corr_coeff=0.0
# n=6, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8484989635991994
# Difference at g=0, h=0, n=6, m=12: corr_coeff2=0.8484989635991994, corr_coeff=0.0
# n=6, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7604357068840555
# Difference at g=0, h=0, n=6, m=13: corr_coeff2=0.7604357068840555, corr_coeff=0.0
# n=6, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8280191252146554
# Difference at g=0, h=0, n=6, m=14: corr_coeff2=0.8280191252146554, corr_coeff=0.0
# n=6, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8709322556360417
# Difference at g=0, h=0, n=6, m=15: corr_coeff2=0.8709322556360417, corr_coeff=0.0
# n=6, m=16, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7640914613563279
# Difference at g=0, h=0, n=6, m=16: corr_coeff2=0.7640914613563279, corr_coeff=0.0
# n=7, m=0, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8667191280716289
# Difference at g=0, h=0, n=7, m=0: corr_coeff2=0.8667191280716289, corr_coeff=0.0
# n=7, m=1, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.875573195635244
# Difference at g=0, h=0, n=7, m=1: corr_coeff2=0.875573195635244, corr_coeff=0.0
# n=7, m=2, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8421732648105078
# Difference at g=0, h=0, n=7, m=2: corr_coeff2=0.8421732648105078, corr_coeff=0.0
# n=7, m=3, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8412435091549898
# Difference at g=0, h=0, n=7, m=3: corr_coeff2=0.8412435091549898, corr_coeff=0.0
# n=7, m=4, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8346276134158677
# Difference at g=0, h=0, n=7, m=4: corr_coeff2=0.8346276134158677, corr_coeff=0.0
# n=7, m=5, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8139530232640904
# Difference at g=0, h=0, n=7, m=5: corr_coeff2=0.8139530232640904, corr_coeff=0.0
# n=7, m=6, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7897823486603947
# Difference at g=0, h=0, n=7, m=6: corr_coeff2=0.7897823486603947, corr_coeff=0.0
# n=7, m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=0, h=0, n=7, m=7: corr_coeff2=1.0, corr_coeff=0.0
# n=7, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9335244463889061
# Difference at g=0, h=0, n=7, m=8: corr_coeff2=0.9335244463889061, corr_coeff=0.0
# n=7, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.812594917957419
# Difference at g=0, h=0, n=7, m=9: corr_coeff2=0.812594917957419, corr_coeff=0.0
# n=7, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8875277989135452
# Difference at g=0, h=0, n=7, m=10: corr_coeff2=0.8875277989135452, corr_coeff=0.0
# n=7, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9207649723832744
# Difference at g=0, h=0, n=7, m=11: corr_coeff2=0.9207649723832744, corr_coeff=0.0
# n=7, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8117588908223534
# Difference at g=0, h=0, n=7, m=12: corr_coeff2=0.8117588908223534, corr_coeff=0.0
# n=7, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8310282540363911
# Difference at g=0, h=0, n=7, m=13: corr_coeff2=0.8310282540363911, corr_coeff=0.0
# n=7, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8184059161032634
# Difference at g=0, h=0, n=7, m=14: corr_coeff2=0.8184059161032634, corr_coeff=0.0
# n=7, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.761479698487765
# Difference at g=0, h=0, n=7, m=15: corr_coeff2=0.761479698487765, corr_coeff=0.0
# n=7, m=16, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8004848930428812
# Difference at g=0, h=0, n=7, m=16: corr_coeff2=0.8004848930428812, corr_coeff=0.0
# n=8, m=0, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9232156392784633
# Difference at g=0, h=0, n=8, m=0: corr_coeff2=0.9232156392784633, corr_coeff=0.0
# n=8, m=1, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9149434662242366
# Difference at g=0, h=0, n=8, m=1: corr_coeff2=0.9149434662242366, corr_coeff=0.0
# n=8, m=2, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.909874289561796
# Difference at g=0, h=0, n=8, m=2: corr_coeff2=0.909874289561796, corr_coeff=0.0
# n=8, m=3, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9229875580851554
# Difference at g=0, h=0, n=8, m=3: corr_coeff2=0.9229875580851554, corr_coeff=0.0
# n=8, m=4, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8952616290578532
# Difference at g=0, h=0, n=8, m=4: corr_coeff2=0.8952616290578532, corr_coeff=0.0
# n=8, m=5, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8521539517389077
# Difference at g=0, h=0, n=8, m=5: corr_coeff2=0.8521539517389077, corr_coeff=0.0
# n=8, m=6, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8457674554130287
# Difference at g=0, h=0, n=8, m=6: corr_coeff2=0.8457674554130287, corr_coeff=0.0
# n=8, m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.933524446388906
# Difference at g=0, h=0, n=8, m=7: corr_coeff2=0.933524446388906, corr_coeff=0.0
# n=8, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=0, h=0, n=8, m=8: corr_coeff2=1.0, corr_coeff=0.0
# n=8, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7548108936796307
# Difference at g=0, h=0, n=8, m=9: corr_coeff2=0.7548108936796307, corr_coeff=0.0
# n=8, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.951197384719504
# Difference at g=0, h=0, n=8, m=10: corr_coeff2=0.951197384719504, corr_coeff=0.0
# n=8, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9161807313783641
# Difference at g=0, h=0, n=8, m=11: corr_coeff2=0.9161807313783641, corr_coeff=0.0
# n=8, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8956990329336573
# Difference at g=0, h=0, n=8, m=12: corr_coeff2=0.8956990329336573, corr_coeff=0.0
# n=8, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8265716449625878
# Difference at g=0, h=0, n=8, m=13: corr_coeff2=0.8265716449625878, corr_coeff=0.0
# n=8, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8858314848947898
# Difference at g=0, h=0, n=8, m=14: corr_coeff2=0.8858314848947898, corr_coeff=0.0
# n=8, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8501242029664924
# Difference at g=0, h=0, n=8, m=15: corr_coeff2=0.8501242029664924, corr_coeff=0.0
# n=8, m=16, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8563636786420267
# Difference at g=0, h=0, n=8, m=16: corr_coeff2=0.8563636786420267, corr_coeff=0.0
# n=9, m=0, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7079754575427762
# Difference at g=0, h=0, n=9, m=0: corr_coeff2=0.7079754575427762, corr_coeff=0.0
# n=9, m=1, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7397284151364037
# Difference at g=0, h=0, n=9, m=1: corr_coeff2=0.7397284151364037, corr_coeff=0.0
# n=9, m=2, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6769817800752718
# Difference at g=0, h=0, n=9, m=2: corr_coeff2=0.6769817800752718, corr_coeff=0.0
# n=9, m=3, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6974489685904395
# Difference at g=0, h=0, n=9, m=3: corr_coeff2=0.6974489685904395, corr_coeff=0.0
# n=9, m=4, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.705497337760744
# Difference at g=0, h=0, n=9, m=4: corr_coeff2=0.705497337760744, corr_coeff=0.0
# n=9, m=5, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7753926416382189
# Difference at g=0, h=0, n=9, m=5: corr_coeff2=0.7753926416382189, corr_coeff=0.0
# n=9, m=6, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7602385506950997
# Difference at g=0, h=0, n=9, m=6: corr_coeff2=0.7602385506950997, corr_coeff=0.0
# n=9, m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8125949179574189
# Difference at g=0, h=0, n=9, m=7: corr_coeff2=0.8125949179574189, corr_coeff=0.0
# n=9, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7548108936796307
# Difference at g=0, h=0, n=9, m=8: corr_coeff2=0.7548108936796307, corr_coeff=0.0
# n=9, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9999999999999998
# Difference at g=0, h=0, n=9, m=9: corr_coeff2=0.9999999999999998, corr_coeff=0.0
# n=9, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7414368201662972
# Difference at g=0, h=0, n=9, m=10: corr_coeff2=0.7414368201662972, corr_coeff=0.0
# n=9, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.916185717640766
# Difference at g=0, h=0, n=9, m=11: corr_coeff2=0.916185717640766, corr_coeff=0.0
# n=9, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6988428110800341
# Difference at g=0, h=0, n=9, m=12: corr_coeff2=0.6988428110800341, corr_coeff=0.0
# n=9, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6690588898565061
# Difference at g=0, h=0, n=9, m=13: corr_coeff2=0.6690588898565061, corr_coeff=0.0
# n=9, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6768173830008314
# Difference at g=0, h=0, n=9, m=14: corr_coeff2=0.6768173830008314, corr_coeff=0.0
# n=9, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6577491278614994
# Difference at g=0, h=0, n=9, m=15: corr_coeff2=0.6577491278614994, corr_coeff=0.0
# n=9, m=16, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6396663603139869
# Difference at g=0, h=0, n=9, m=16: corr_coeff2=0.6396663603139869, corr_coeff=0.0
# n=10, m=0, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9185492107077885
# Difference at g=0, h=0, n=10, m=0: corr_coeff2=0.9185492107077885, corr_coeff=0.0
# n=10, m=1, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9168614672914073
# Difference at g=0, h=0, n=10, m=1: corr_coeff2=0.9168614672914073, corr_coeff=0.0
# n=10, m=2, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9000240669147904
# Difference at g=0, h=0, n=10, m=2: corr_coeff2=0.9000240669147904, corr_coeff=0.0
# n=10, m=3, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9116979388607129
# Difference at g=0, h=0, n=10, m=3: corr_coeff2=0.9116979388607129, corr_coeff=0.0
# n=10, m=4, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8546486234808656
# Difference at g=0, h=0, n=10, m=4: corr_coeff2=0.8546486234808656, corr_coeff=0.0
# n=10, m=5, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8458983504475717
# Difference at g=0, h=0, n=10, m=5: corr_coeff2=0.8458983504475717, corr_coeff=0.0
# n=10, m=6, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8701281004884582
# Difference at g=0, h=0, n=10, m=6: corr_coeff2=0.8701281004884582, corr_coeff=0.0
# n=10, m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.887527798913545
# Difference at g=0, h=0, n=10, m=7: corr_coeff2=0.887527798913545, corr_coeff=0.0
# n=10, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.951197384719504
# Difference at g=0, h=0, n=10, m=8: corr_coeff2=0.951197384719504, corr_coeff=0.0
# n=10, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7414368201662973
# Difference at g=0, h=0, n=10, m=9: corr_coeff2=0.7414368201662973, corr_coeff=0.0
# n=10, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9999999999999999
# Difference at g=0, h=0, n=10, m=10: corr_coeff2=0.9999999999999999, corr_coeff=0.0
# n=10, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.91044216633942
# Difference at g=0, h=0, n=10, m=11: corr_coeff2=0.91044216633942, corr_coeff=0.0
# n=10, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8458778047369985
# Difference at g=0, h=0, n=10, m=12: corr_coeff2=0.8458778047369985, corr_coeff=0.0
# n=10, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7508422358189272
# Difference at g=0, h=0, n=10, m=13: corr_coeff2=0.7508422358189272, corr_coeff=0.0
# n=10, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8191850761042091
# Difference at g=0, h=0, n=10, m=14: corr_coeff2=0.8191850761042091, corr_coeff=0.0
# n=10, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7976366461506915
# Difference at g=0, h=0, n=10, m=15: corr_coeff2=0.7976366461506915, corr_coeff=0.0
# n=10, m=16, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7821685736602892
# Difference at g=0, h=0, n=10, m=16: corr_coeff2=0.7821685736602892, corr_coeff=0.0
# n=11, m=0, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8549707870540497
# Difference at g=0, h=0, n=11, m=0: corr_coeff2=0.8549707870540497, corr_coeff=0.0
# n=11, m=1, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8681057860969704
# Difference at g=0, h=0, n=11, m=1: corr_coeff2=0.8681057860969704, corr_coeff=0.0
# n=11, m=2, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8320378395179634
# Difference at g=0, h=0, n=11, m=2: corr_coeff2=0.8320378395179634, corr_coeff=0.0
# n=11, m=3, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8585054014720543
# Difference at g=0, h=0, n=11, m=3: corr_coeff2=0.8585054014720543, corr_coeff=0.0
# n=11, m=4, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8376169141171261
# Difference at g=0, h=0, n=11, m=4: corr_coeff2=0.8376169141171261, corr_coeff=0.0
# n=11, m=5, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8367596943846349
# Difference at g=0, h=0, n=11, m=5: corr_coeff2=0.8367596943846349, corr_coeff=0.0
# n=11, m=6, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8362997242203113
# Difference at g=0, h=0, n=11, m=6: corr_coeff2=0.8362997242203113, corr_coeff=0.0
# n=11, m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9207649723832745
# Difference at g=0, h=0, n=11, m=7: corr_coeff2=0.9207649723832745, corr_coeff=0.0
# n=11, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.916180731378364
# Difference at g=0, h=0, n=11, m=8: corr_coeff2=0.916180731378364, corr_coeff=0.0
# n=11, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9161857176407661
# Difference at g=0, h=0, n=11, m=9: corr_coeff2=0.9161857176407661, corr_coeff=0.0
# n=11, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9104421663394199
# Difference at g=0, h=0, n=11, m=10: corr_coeff2=0.9104421663394199, corr_coeff=0.0
# n=11, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=0, h=0, n=11, m=11: corr_coeff2=1.0, corr_coeff=0.0
# n=11, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.820267464590983
# Difference at g=0, h=0, n=11, m=12: corr_coeff2=0.820267464590983, corr_coeff=0.0
# n=11, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7538443150953983
# Difference at g=0, h=0, n=11, m=13: corr_coeff2=0.7538443150953983, corr_coeff=0.0
# n=11, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7857911558047476
# Difference at g=0, h=0, n=11, m=14: corr_coeff2=0.7857911558047476, corr_coeff=0.0
# n=11, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7369434165715024
# Difference at g=0, h=0, n=11, m=15: corr_coeff2=0.7369434165715024, corr_coeff=0.0
# n=11, m=16, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7506470677506758
# Difference at g=0, h=0, n=11, m=16: corr_coeff2=0.7506470677506758, corr_coeff=0.0
# n=12, m=0, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.905438398987375
# Difference at g=0, h=0, n=12, m=0: corr_coeff2=0.905438398987375, corr_coeff=0.0
# n=12, m=1, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8758578730468864
# Difference at g=0, h=0, n=12, m=1: corr_coeff2=0.8758578730468864, corr_coeff=0.0
# n=12, m=2, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.918555332366098
# Difference at g=0, h=0, n=12, m=2: corr_coeff2=0.918555332366098, corr_coeff=0.0
# n=12, m=3, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9428307893847977
# Difference at g=0, h=0, n=12, m=3: corr_coeff2=0.9428307893847977, corr_coeff=0.0
# n=12, m=4, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9561226005704648
# Difference at g=0, h=0, n=12, m=4: corr_coeff2=0.9561226005704648, corr_coeff=0.0
# n=12, m=5, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8497366640574358
# Difference at g=0, h=0, n=12, m=5: corr_coeff2=0.8497366640574358, corr_coeff=0.0
# n=12, m=6, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8484989635991989
# Difference at g=0, h=0, n=12, m=6: corr_coeff2=0.8484989635991989, corr_coeff=0.0
# n=12, m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8117588908223534
# Difference at g=0, h=0, n=12, m=7: corr_coeff2=0.8117588908223534, corr_coeff=0.0
# n=12, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8956990329336573
# Difference at g=0, h=0, n=12, m=8: corr_coeff2=0.8956990329336573, corr_coeff=0.0
# n=12, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6988428110800341
# Difference at g=0, h=0, n=12, m=9: corr_coeff2=0.6988428110800341, corr_coeff=0.0
# n=12, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8458778047369985
# Difference at g=0, h=0, n=12, m=10: corr_coeff2=0.8458778047369985, corr_coeff=0.0
# n=12, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8202674645909829
# Difference at g=0, h=0, n=12, m=11: corr_coeff2=0.8202674645909829, corr_coeff=0.0
# n=12, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9999999999999999
# Difference at g=0, h=0, n=12, m=12: corr_coeff2=0.9999999999999999, corr_coeff=0.0
# n=12, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8471193600561273
# Difference at g=0, h=0, n=12, m=13: corr_coeff2=0.8471193600561273, corr_coeff=0.0
# n=12, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9393993304501856
# Difference at g=0, h=0, n=12, m=14: corr_coeff2=0.9393993304501856, corr_coeff=0.0
# n=12, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.
m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9472138369926714
# Difference at g=0, h=0, n=15, m=14: corr_coeff2=0.9472138369926714, corr_coeff=0.0
# n=15, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=0, h=0, n=15, m=15: corr_coeff2=1.0, corr_coeff=0.0
# n=15, m=16, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9027004016778737
# Difference at g=0, h=0, n=15, m=16: corr_coeff2=0.9027004016778737, corr_coeff=0.0
# n=16, m=0, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8322068186894669
# Difference at g=0, h=0, n=16, m=0: corr_coeff2=0.8322068186894669, corr_coeff=0.0
# n=16, m=1, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.810010562162254
# Difference at g=0, h=0, n=16, m=1: corr_coeff2=0.810010562162254, corr_coeff=0.0
# n=16, m=2, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.84701440823958
# Difference at g=0, h=0, n=16, m=2: corr_coeff2=0.84701440823958, corr_coeff=0.0
# n=16, m=3, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8600460943187397
# Difference at g=0, h=0, n=16, m=3: corr_coeff2=0.8600460943187397, corr_coeff=0.0
# n=16, m=4, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8842401508115272
# Difference at g=0, h=0, n=16, m=4: corr_coeff2=0.8842401508115272, corr_coeff=0.0
# n=16, m=5, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7885104470134583
# Difference at g=0, h=0, n=16, m=5: corr_coeff2=0.7885104470134583, corr_coeff=0.0
# n=16, m=6, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7640914613563257
# Difference at g=0, h=0, n=16, m=6: corr_coeff2=0.7640914613563257, corr_coeff=0.0
# n=16, m=7, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8004848930428777
# Difference at g=0, h=0, n=16, m=7: corr_coeff2=0.8004848930428777, corr_coeff=0.0
# n=16, m=8, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8563636786420266
# Difference at g=0, h=0, n=16, m=8: corr_coeff2=0.8563636786420266, corr_coeff=0.0
# n=16, m=9, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6396663603139876
# Difference at g=0, h=0, n=16, m=9: corr_coeff2=0.6396663603139876, corr_coeff=0.0
# n=16, m=10, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7821685736602879
# Difference at g=0, h=0, n=16, m=10: corr_coeff2=0.7821685736602879, corr_coeff=0.0
# n=16, m=11, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7506470677506746
# Difference at g=0, h=0, n=16, m=11: corr_coeff2=0.7506470677506746, corr_coeff=0.0
# n=16, m=12, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9437486494866268
# Difference at g=0, h=0, n=16, m=12: corr_coeff2=0.9437486494866268, corr_coeff=0.0
# n=16, m=13, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8823486416881672
# Difference at g=0, h=0, n=16, m=13: corr_coeff2=0.8823486416881672, corr_coeff=0.0
# n=16, m=14, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9522798586544505
# Difference at g=0, h=0, n=16, m=14: corr_coeff2=0.9522798586544505, corr_coeff=0.0
# n=16, m=15, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9027004016778722
# Difference at g=0, h=0, n=16, m=15: corr_coeff2=0.9027004016778722, corr_coeff=0.0
# n=16, m=16, g=0, h=0: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9999999999999986
# Difference at g=0, h=0, n=16, m=16: corr_coeff2=0.9999999999999986, corr_coeff=0.0
# n=0, m=0, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=1, h=1, n=0, m=0: corr_coeff2=1.0, corr_coeff=0.0
# ...
# n=11, m=6, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7751605872646324
# Difference at g=1, h=1, n=11, m=6: corr_coeff2=0.7751605872646324, corr_coeff=0.0
# n=11, m=7, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7881568542580989
# Difference at g=1, h=1, n=11, m=7: corr_coeff2=0.7881568542580989, corr_coeff=0.0
# n=11, m=8, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8414721264697683
# Difference at g=1, h=1, n=11, m=8: corr_coeff2=0.8414721264697683, corr_coeff=0.0
# n=11, m=9, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6864765963321076
# Difference at g=1, h=1, n=11, m=9: corr_coeff2=0.6864765963321076, corr_coeff=0.0
# n=11, m=10, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8272297766510913
# Difference at g=1, h=1, n=11, m=10: corr_coeff2=0.8272297766510913, corr_coeff=0.0
# n=11, m=11, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9999999999999999
# Difference at g=1, h=1, n=11, m=11: corr_coeff2=0.9999999999999999, corr_coeff=0.0
# n=11, m=12, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7977572590034518
# Difference at g=1, h=1, n=11, m=12: corr_coeff2=0.7977572590034518, corr_coeff=0.0
# n=11, m=13, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6700417910977103
# Difference at g=1, h=1, n=11, m=13: corr_coeff2=0.6700417910977103, corr_coeff=0.0
# n=11, m=14, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6700417910977103
# Difference at g=1, h=1, n=11, m=14: corr_coeff2=0.6700417910977103, corr_coeff=0.0
# n=11, m=15, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.847689204105792
# Difference at g=1, h=1, n=11, m=15: corr_coeff2=0.847689204105792, corr_coeff=0.0
# n=11, m=16, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7076462638435994
# Difference at g=1, h=1, n=11, m=16: corr_coeff2=0.7076462638435994, corr_coeff=0.0
# n=12, m=0, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8995308899046763
# Difference at g=1, h=1, n=12, m=0: corr_coeff2=0.8995308899046763, corr_coeff=0.0
# n=12, m=1, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9849350052893616
# Difference at g=1, h=1, n=12, m=1: corr_coeff2=0.9849350052893616, corr_coeff=0.0
# n=12, m=2, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9873406390399077
# Difference at g=1, h=1, n=12, m=2: corr_coeff2=0.9873406390399077, corr_coeff=0.0
# n=12, m=3, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9873406390399077
# Difference at g=1, h=1, n=12, m=3: corr_coeff2=0.9873406390399077, corr_coeff=0.0
# n=12, m=4, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8995308899046763
# Difference at g=1, h=1, n=12, m=4: corr_coeff2=0.8995308899046763, corr_coeff=0.0
# n=12, m=5, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9838701823324218
# Difference at g=1, h=1, n=12, m=5: corr_coeff2=0.9838701823324218, corr_coeff=0.0
# n=12, m=6, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7598513436139379
# Difference at g=1, h=1, n=12, m=6: corr_coeff2=0.7598513436139379, corr_coeff=0.0
# n=12, m=7, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.5522240089709873
# Difference at g=1, h=1, n=12, m=7: corr_coeff2=0.5522240089709873, corr_coeff=0.0
# n=12, m=8, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6385173999830721
# Difference at g=1, h=1, n=12, m=8: corr_coeff2=0.6385173999830721, corr_coeff=0.0
# n=12, m=9, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6716198272017928
# Difference at g=1, h=1, n=12, m=9: corr_coeff2=0.6716198272017928, corr_coeff=0.0
# n=12, m=10, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8228837906307777
# Difference at g=1, h=1, n=12, m=10: corr_coeff2=0.8228837906307777, corr_coeff=0.0
# n=12, m=11, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7977572590034518
# Difference at g=1, h=1, n=12, m=11: corr_coeff2=0.7977572590034518, corr_coeff=0.0
# n=12, m=12, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=1, h=1, n=12, m=12: corr_coeff2=1.0, corr_coeff=0.0
# n=12, m=13, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6936821367587768
# Difference at g=1, h=1, n=12, m=13: corr_coeff2=0.6936821367587768, corr_coeff=0.0
# n=12, m=14, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6936821367587768
# Difference at g=1, h=1, n=12, m=14: corr_coeff2=0.6936821367587768, corr_coeff=0.0
# n=12, m=15, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7980803609773404
# Difference at g=1, h=1, n=12, m=15: corr_coeff2=0.7980803609773404, corr_coeff=0.0
# n=12, m=16, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9121907951614145
# Difference at g=1, h=1, n=12, m=16: corr_coeff2=0.9121907951614145, corr_coeff=0.0
# n=13, m=0, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6698376637603475
# Difference at g=1, h=1, n=13, m=0: corr_coeff2=0.6698376637603475, corr_coeff=0.0
# n=13, m=1, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6351289588590104
# Difference at g=1, h=1, n=13, m=1: corr_coeff2=0.6351289588590104, corr_coeff=0.0
# n=13, m=2, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7035499060921131
# Difference at g=1, h=1, n=13, m=2: corr_coeff2=0.7035499060921131, corr_coeff=0.0
# n=13, m=3, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7035499060921131
# Difference at g=1, h=1, n=13, m=3: corr_coeff2=0.7035499060921131, corr_coeff=0.0
# n=13, m=4, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6698376637603475
# Difference at g=1, h=1, n=13, m=4: corr_coeff2=0.6698376637603475, corr_coeff=0.0
# n=13, m=5, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7043795462678403
# Difference at g=1, h=1, n=13, m=5: corr_coeff2=0.7043795462678403, corr_coeff=0.0
# n=13, m=6, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9665700744245092
# Difference at g=1, h=1, n=13, m=6: corr_coeff2=0.9665700744245092, corr_coeff=0.0
# n=13, m=7, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.3578658921266631
# Difference at g=1, h=1, n=13, m=7: corr_coeff2=0.3578658921266631, corr_coeff=0.0
# n=13, m=8, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.5081185124788545
# Difference at g=1, h=1, n=13, m=8: corr_coeff2=0.5081185124788545, corr_coeff=0.0
# n=13, m=9, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8419921684351113
# Difference at g=1, h=1, n=13, m=9: corr_coeff2=0.8419921684351113, corr_coeff=0.0
# n=13, m=10, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6602056313747363
# Difference at g=1, h=1, n=13, m=10: corr_coeff2=0.6602056313747363, corr_coeff=0.0
# n=13, m=11, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6700417910977102
# Difference at g=1, h=1, n=13, m=11: corr_coeff2=0.6700417910977102, corr_coeff=0.0
# n=13, m=12, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6936821367587768
# Difference at g=1, h=1, n=13, m=12: corr_coeff2=0.6936821367587768, corr_coeff=0.0
# n=13, m=13, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=1, h=1, n=13, m=13: corr_coeff2=1.0, corr_coeff=0.0
# n=13, m=14, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=1, h=1, n=13, m=14: corr_coeff2=1.0, corr_coeff=0.0
# n=13, m=15, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8163212115448557
# Difference at g=1, h=1, n=13, m=15: corr_coeff2=0.8163212115448557, corr_coeff=0.0
# n=13, m=16, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6903426849433496
# Difference at g=1, h=1, n=13, m=16: corr_coeff2=0.6903426849433496, corr_coeff=0.0
# n=14, m=0, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6698376637603475
# Difference at g=1, h=1, n=14, m=0: corr_coeff2=0.6698376637603475, corr_coeff=0.0
# n=14, m=1, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6351289588590104
# Difference at g=1, h=1, n=14, m=1: corr_coeff2=0.6351289588590104, corr_coeff=0.0
# n=14, m=2, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7035499060921131
# Difference at g=1, h=1, n=14, m=2: corr_coeff2=0.7035499060921131, corr_coeff=0.0
# n=14, m=3, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7035499060921131
# Difference at g=1, h=1, n=14, m=3: corr_coeff2=0.7035499060921131, corr_coeff=0.0
# n=14, m=4, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6698376637603475
# Difference at g=1, h=1, n=14, m=4: corr_coeff2=0.6698376637603475, corr_coeff=0.0
# n=14, m=5, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7043795462678403
# Difference at g=1, h=1, n=14, m=5: corr_coeff2=0.7043795462678403, corr_coeff=0.0
# n=14, m=6, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9665700744245092
# Difference at g=1, h=1, n=14, m=6: corr_coeff2=0.9665700744245092, corr_coeff=0.0
# n=14, m=7, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.3578658921266631
# Difference at g=1, h=1, n=14, m=7: corr_coeff2=0.3578658921266631, corr_coeff=0.0
# n=14, m=8, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.5081185124788545
# Difference at g=1, h=1, n=14, m=8: corr_coeff2=0.5081185124788545, corr_coeff=0.0
# n=14, m=9, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8419921684351113
# Difference at g=1, h=1, n=14, m=9: corr_coeff2=0.8419921684351113, corr_coeff=0.0
# n=14, m=10, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6602056313747363
# Difference at g=1, h=1, n=14, m=10: corr_coeff2=0.6602056313747363, corr_coeff=0.0
# n=14, m=11, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6700417910977102
# Difference at g=1, h=1, n=14, m=11: corr_coeff2=0.6700417910977102, corr_coeff=0.0
# n=14, m=12, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6936821367587768
# Difference at g=1, h=1, n=14, m=12: corr_coeff2=0.6936821367587768, corr_coeff=0.0
# n=14, m=13, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=1, h=1, n=14, m=13: corr_coeff2=1.0, corr_coeff=0.0
# n=14, m=14, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=1, h=1, n=14, m=14: corr_coeff2=1.0, corr_coeff=0.0
# n=14, m=15, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8163212115448557
# Difference at g=1, h=1, n=14, m=15: corr_coeff2=0.8163212115448557, corr_coeff=0.0
# n=14, m=16, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6903426849433496
# Difference at g=1, h=1, n=14, m=16: corr_coeff2=0.6903426849433496, corr_coeff=0.0
# n=15, m=0, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.766014159277988
# Difference at g=1, h=1, n=15, m=0: corr_coeff2=0.766014159277988, corr_coeff=0.0
# n=15, m=1, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.759989645115677
# Difference at g=1, h=1, n=15, m=1: corr_coeff2=0.759989645115677, corr_coeff=0.0
# n=15, m=2, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8099664317331644
# Difference at g=1, h=1, n=15, m=2: corr_coeff2=0.8099664317331644, corr_coeff=0.0
# n=15, m=3, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8099664317331644
# Difference at g=1, h=1, n=15, m=3: corr_coeff2=0.8099664317331644, corr_coeff=0.0
# n=15, m=4, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.766014159277988
# Difference at g=1, h=1, n=15, m=4: corr_coeff2=0.766014159277988, corr_coeff=0.0
# n=15, m=5, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8079032188147264
# Difference at g=1, h=1, n=15, m=5: corr_coeff2=0.8079032188147264, corr_coeff=0.0
# n=15, m=6, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9217685582432319
# Difference at g=1, h=1, n=15, m=6: corr_coeff2=0.9217685582432319, corr_coeff=0.0
# n=15, m=7, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.5512355304876907
# Difference at g=1, h=1, n=15, m=7: corr_coeff2=0.5512355304876907, corr_coeff=0.0
# n=15, m=8, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6851013824257309
# Difference at g=1, h=1, n=15, m=8: corr_coeff2=0.6851013824257309, corr_coeff=0.0
# n=15, m=9, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7663776596450325
# Difference at g=1, h=1, n=15, m=9: corr_coeff2=0.7663776596450325, corr_coeff=0.0
# n=15, m=10, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8510417723317613
# Difference at g=1, h=1, n=15, m=10: corr_coeff2=0.8510417723317613, corr_coeff=0.0
# n=15, m=11, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8476892041057924
# Difference at g=1, h=1, n=15, m=11: corr_coeff2=0.8476892041057924, corr_coeff=0.0
# n=15, m=12, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7980803609773401
# Difference at g=1, h=1, n=15, m=12: corr_coeff2=0.7980803609773401, corr_coeff=0.0
# n=15, m=13, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8163212115448566
# Difference at g=1, h=1, n=15, m=13: corr_coeff2=0.8163212115448566, corr_coeff=0.0
# n=15, m=14, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8163212115448557
# Difference at g=1, h=1, n=15, m=14: corr_coeff2=0.8163212115448557, corr_coeff=0.0
# n=15, m=15, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=1.0
# Difference at g=1, h=1, n=15, m=15: corr_coeff2=1.0, corr_coeff=0.0
# n=15, m=16, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.748173749222839
# Difference at g=1, h=1, n=15, m=16: corr_coeff2=0.748173749222839, corr_coeff=0.0
# n=16, m=0, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.877849923189256
# Difference at g=1, h=1, n=16, m=0: corr_coeff2=0.877849923189256, corr_coeff=0.0
# n=16, m=1, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8715828708431207
# Difference at g=1, h=1, n=16, m=1: corr_coeff2=0.8715828708431207, corr_coeff=0.0
# n=16, m=2, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8846776800294137
# Difference at g=1, h=1, n=16, m=2: corr_coeff2=0.8846776800294137, corr_coeff=0.0
# n=16, m=3, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.8846776800294137
# Difference at g=1, h=1, n=16, m=3: corr_coeff2=0.8846776800294137, corr_coeff=0.0
# n=16, m=4, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.877849923189256
# Difference at g=1, h=1, n=16, m=4: corr_coeff2=0.877849923189256, corr_coeff=0.0
# n=16, m=5, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.884870592643748
# Difference at g=1, h=1, n=16, m=5: corr_coeff2=0.884870592643748, corr_coeff=0.0
# n=16, m=6, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.738564585699157
# Difference at g=1, h=1, n=16, m=6: corr_coeff2=0.738564585699157, corr_coeff=0.0
# n=16, m=7, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.45633844320512396
# Difference at g=1, h=1, n=16, m=7: corr_coeff2=0.45633844320512396, corr_coeff=0.0
# n=16, m=8, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.5831015428706989
# Difference at g=1, h=1, n=16, m=8: corr_coeff2=0.5831015428706989, corr_coeff=0.0
# n=16, m=9, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6694772490237726
# Difference at g=1, h=1, n=16, m=9: corr_coeff2=0.6694772490237726, corr_coeff=0.0
# n=16, m=10, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7545665384929278
# Difference at g=1, h=1, n=16, m=10: corr_coeff2=0.7545665384929278, corr_coeff=0.0
# n=16, m=11, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7076462638435993
# Difference at g=1, h=1, n=16, m=11: corr_coeff2=0.7076462638435993, corr_coeff=0.0
# n=16, m=12, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9121907951614143
# Difference at g=1, h=1, n=16, m=12: corr_coeff2=0.9121907951614143, corr_coeff=0.0
# n=16, m=13, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6903426849433493
# Difference at g=1, h=1, n=16, m=13: corr_coeff2=0.6903426849433493, corr_coeff=0.0
# n=16, m=14, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.6903426849433486
# Difference at g=1, h=1, n=16, m=14: corr_coeff2=0.6903426849433486, corr_coeff=0.0
# n=16, m=15, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.7481737492228387
# Difference at g=1, h=1, n=16, m=15: corr_coeff2=0.7481737492228387, corr_coeff=0.0
# n=16, m=16, g=1, h=1: corr_coeff=0.0, corr_coeff1=0.0, corr_coeff2=0.9999999999999999
# Difference at g=1, h=1, n=16, m=16: corr_coeff2=0.9999999999999999, corr_coeff=0.0

# %%
import spatial_agg_objoriented as saoo
import spatial_agg as sa

lines_df, nodes_df, wind_df, solar_df = sa.import_data()
time_series_dict = {
     'wind': wind_df,
     'solar': solar_df
 }
TimeHorizon = 24
CF = sa.create_capacity_factor_array(nodes_df, TimeSeriesList, TimeHorizon)
N_prime = 10
lambdas = [1,1,1]
N, G, T = CF.shape;


network = saoo.Network(nodes_df, time_series_dict, lines_df, TimeHorizon)
network.display_node_features(0)

# optimizer = AggregationOptimizer(network, target_node_count=2)
# optimizer.optimize_aggregation()
# optimizer.display_aggregated_network()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       5 time_series_dict = {
#       6      'wind': wind_df,
#       7      'solar': solar_df
#       8  }
#       9 TimeHorizon = 24
# ---> 10 CF = sa.create_capacity_factor_array(nodes_df, TimeSeriesList, TimeHorizon)
#      11 N_prime = 10
#      12 lambdas = [1,1,1]
#
# NameError: name 'TimeSeriesList' is not defined
