# %% [markdown]
# ## Aggregate the network with an optimization method

# %%
import sys
sys.path.append('../src')
import utils
import models as m
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from itertools import product
import importlib

importlib.reload(m)
importlib.reload(utils)
# Out:
# <module 'utils' from 'c:\\Users\\g630d\\Documents\\00_Cours\\2024-2025_MIT\\00 Thesis\\Dev\\notebooks\\../src\\utils.py'>

# %%
nodes_df, wind_df, solar_df = utils.import_data_county()
TimeSeries = {'wind': wind_df.iloc[:, 1:], 'solar': solar_df.iloc[:, 1:]};

# %%
network = utils.Network(nodes_df, TimeSeries)
# Out:
# The 'features' dictionary has been created and can be accessed as '.features'
# It is a dictionary with keys for each node in range(0, 67).
# Each value is a dictionary with the features of that node.
#
# Example structure:
# network.features[0].keys() = dict_keys(['position', 'time_series', 'duration_curves', 'ramp_duration_curves', 'correlation'])
#
# Details:
#   - Position: A tuple (latitude, longitude) of that node.
#   - Time series: A dictionary with keys for each time series type in dict_keys(['wind', 'solar'])
#     and values as the time series itself.
#   - Duration Curves: A dictionary with keys for each time series type in dict_keys(['wind', 'solar'])
#     and values as the duration curve of the time series.
#   - Ramp Duration Curves (RDCs): A dictionary with keys for each time series type dict_keys(['wind', 'solar'])
#     and values as the RDC (found by differentiating and subsequently sorting) of the time series.
#   - Correlation: A dictionary with keys as tuples of types of time series
#     and values as correlation factors between those time series.

# %%
node_features = network.features;

# %%
# Define parameter grid
weights_list = [
    {'position': 1, 'time_series': 1, 'duration_curves': 1, 'rdc': 1, 'intra_correlation': 1, 'inter_correlation': 1},
    {'position': 3, 'time_series': 1, 'duration_curves': 1, 'rdc': 1, 'intra_correlation': 1, 'inter_correlation': 1},
    {'position': 1, 'time_series': 2, 'duration_curves': 1, 'rdc': 1, 'intra_correlation': 1, 'inter_correlation': 1}
]
n_repr_values = [5, 8, 10, 15, 20]
n_kmedoids_iterations = 10  # Number of KMedoids iterations per configuration

# %%
aggregator = m.Aggregation(node_features, 10)

# %%
results = []

original_features = node_features

# Iterate over all combinations
for weights, n_repr in product(weights_list, n_repr_values):
    # Create Aggregator
    aggregator = m.Aggregation(node_features, n_repr)
    
    # Optimize and cluster
    u_results, z_results = aggregator.optimize(weights)
    
    for iteration in range(n_kmedoids_iterations):
        clusters_KMedoids, cluster_centers_KMedoids = aggregator.cluster_KMedoids(weights)

        # Prepare aggregated features
        aggregated_features_KMedoids = {}
        for cluster_id, nodes in clusters_KMedoids.items():
            representative = cluster_centers_KMedoids[cluster_id]
            for node in nodes:
                aggregated_features_KMedoids[node] = node_features[representative]

        aggregated_features_optimized = {}
        for i, selected in enumerate(z_results):
            if selected:
                for j in range(len(u_results)):
                    if u_results[j, i] == 1:
                        aggregated_features_optimized[j] = node_features[i]

        # Compute metrics
        eval = m.AggregationMetrics(original_features)
        eval_metrics_optimized = eval.compute_metrics(aggregated_features_optimized)
        eval_metrics_KMedoids = eval.compute_metrics(aggregated_features_KMedoids)

        # Store results
        results.append({
            'weights': weights,
            'n_repr': n_repr,
            'iteration': iteration,
            'optimized_metrics': eval_metrics_optimized,
            'kmedoids_metrics': eval_metrics_KMedoids
        })
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09

# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4557 rows, 4556 columns and 13534 nonzeros
# Model fingerprint: 0xb6f7d6da
# Variable types: 0 continuous, 4556 integer (4556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Presolve time: 0.03s
# Presolved: 4557 rows, 4556 columns, 13534 nonzeros
# Variable types: 0 continuous, 4556 integer (4556 binary)
# Found heuristic solution: objective 93.1694005
#
# Root relaxation: objective 6.160166e+01, 635 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      61.6016623   61.60166  0.00%     -    0s
#
# Explored 1 nodes (635 simplex iterations) in 0.08 seconds (0.07 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 61.6017 93.1694
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.160166226199e+01, best bound 6.160166226199e+01, gap 0.0000%
#
# Optimization Results:
#   - Objective Value: 61.6016622619901
#   - Representatives: [12, 19, 30, 34, 43, 48, 52, 65]
#     - Representative node 12: [5, 6, 7, 10, 11, 12, 14, 15, 44, 61, 63]
#     - Representative node 19: [4, 16, 19, 20, 58]
#     - Representative node 30: [22, 23, 24, 25, 26, 27, 28, 29, 30, 35]
#     - Representative node 34: [32, 33, 34, 36]
#     - Representative node 43: [13, 37, 40, 41, 42, 43, 45, 46, 53, 57, 62, 64, 66]
#     - Representative node 48: [1, 2, 3, 8, 9, 17, 48, 49, 50]
#     - Representative node 52: [0, 21, 51, 52, 59]
#     - Representative node 65: [18, 31, 38, 39, 47, 54, 55, 56, 60, 65]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4557 rows, 4556 columns and 13534 nonzeros
# Model fingerprint: 0x140c217c
# Variable types: 0 continuous, 4556 integer (4556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve time: 0.03s
# Presolved: 4557 rows, 4556 columns, 13534 nonzeros
# Variable types: 0 continuous, 4556 integer (4556 binary)
# Found heuristic solution: objective 85.0185521
#
# Root relaxation: objective 5.556096e+01, 519 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   55.56096    0   36   85.01855   55.56096  34.6%     -    0s
# H    0     0                      55.6795059   55.56096  0.21%     -    0s
# H    0     0                      55.6275743   55.56096  0.12%     -    0s
# H    0     0                      55.5628419   55.56096  0.00%     -    0s
#
# Explored 1 nodes (519 simplex iterations) in 0.11 seconds (0.07 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 55.5628 55.6276 55.6795 85.0186
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.556284192996e+01, best bound 5.556096350799e+01, gap 0.0034%
#
# Optimization Results:
#   - Objective Value: 55.562841929960726
#   - Representatives: [12, 19, 30, 34, 41, 47, 48, 52, 65, 66]
#     - Representative node 12: [5, 6, 7, 11, 12, 14, 15, 44, 61, 63]
#     - Representative node 19: [4, 19, 20, 58]
#     - Representative node 30: [22, 23, 24, 25, 26, 27, 28, 29, 30, 35]
#     - Representative node 34: [32, 33, 34, 36]
#     - Representative node 41: [13, 16, 41, 42, 43, 45]
#     - Representative node 47: [10, 18, 40, 46, 47]
#     - Representative node 48: [1, 2, 3, 8, 9, 17, 48, 49, 50]
#     - Representative node 52: [0, 21, 51, 52, 59]
#     - Representative node 65: [31, 38, 39, 54, 55, 56, 60, 65]
#     - Representative node 66: [37, 53, 57, 62, 64, 66]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4557 rows, 4556 columns and 13534 nonzeros
# Model fingerprint: 0x6c7d5bf5
# Variable types: 0 continuous, 4556 integer (4556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve time: 0.03s
# Presolved: 4557 rows, 4556 columns, 13534 nonzeros
# Variable types: 0 continuous, 4556 integer (4556 binary)
# Found heuristic solution: objective 75.4553518
#
# Root relaxation: objective 4.531811e+01, 395 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   45.31811    0   28   75.45535   45.31811  39.9%     -    0s
# H    0     0                      50.0665567   45.31811  9.48%     -    0s
# H    0     0                      46.6573569   45.31811  2.87%     -    0s
#      0     0   45.35115    0   28   46.65736   45.35115  2.80%     -    0s
#      0     0   45.35115    0   28   46.65736   45.35115  2.80%     -    0s
# H    0     0                      46.0897183   45.35115  1.60%     -    0s
# H    0     0                      45.8918401   45.35115  1.18%     -    0s
#      0     0   45.35115    0   28   45.89184   45.35115  1.18%     -    0s
#      0     0   45.35115    0   24   45.89184   45.35115  1.18%     -    0s
# H    0     0                      45.6718125   45.35115  0.70%     -    0s
# H    0     0                      45.5857948   45.35115  0.51%     -    0s
# H    0     0                      45.4366643   45.35115  0.19%     -    0s
#      0     0   45.36012    0   24   45.43666   45.36012  0.17%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 3
#
# Explored 1 nodes (1059 simplex iterations) in 0.26 seconds (0.13 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 45.4367 45.5858 45.6718 ... 75.4554
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.543666425879e+01, best bound 4.543666425879e+01, gap 0.0000%
#
# Optimization Results:
#   - Objective Value:
     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 2
#
# Explored 1 nodes (649 simplex iterations) in 0.18 seconds (0.10 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 50.2805 71.1079
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.028045540854e+01, best bound 5.028045540854e+01, gap 0.0000%
#
# Optimization Results:
#   - Objective Value: 50.28045540853918
#   - Representatives: [15, 19, 26, 36, 39, 47, 52, 62]
#     - Representative node 15: [5, 6, 11, 12, 13, 14, 15, 16, 28, 41, 42, 43, 45]
#     - Representative node 19: [4, 19, 20, 58]
#     - Representative node 26: [1, 8, 23, 25, 26, 27, 29, 30, 38, 44, 48, 60, 61]
#     - Representative node 36: [17, 32, 33, 34, 36, 56, 59]
#     - Representative node 39: [2, 3, 18, 24, 31, 39, 49, 54, 65]
#     - Representative node 47: [10, 40, 46, 47, 55]
#     - Representative node 52: [0, 7, 9, 21, 22, 50, 51, 52, 57]
#     - Representative node 62: [35, 37, 53, 62, 63, 64, 66]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4557 rows, 4556 columns and 13534 nonzeros
# Model fingerprint: 0x892fa2ef
# Variable types: 0 continuous, 4556 integer (4556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve time: 0.03s
# Presolved: 4557 rows, 4556 columns, 13534 nonzeros
# Variable types: 0 continuous, 4556 integer (4556 binary)
# Found heuristic solution: objective 68.9527035
#
# Root relaxation: objective 4.537889e+01, 508 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      45.3788934   45.37889  0.00%     -    0s
#
# Explored 1 nodes (508 simplex iterations) in 0.09 seconds (0.06 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 45.3789 68.9527
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.537889337010e+01, best bound 4.537889337010e+01, gap 0.0000%
#
# Optimization Results:
#   - Objective Value: 45.378893370097565
#   - Representatives: [4, 15, 27, 36, 47, 48, 52, 58, 60, 62]
#     - Representative node 4: [4]
#     - Representative node 15: [5, 6, 11, 12, 13, 14, 15, 16, 28, 41, 42, 43, 45]
#     - Representative node 27: [23, 24, 26, 27, 29, 30, 31, 38, 39]
#     - Representative node 36: [17, 32, 33, 34, 36, 56, 59]
#     - Representative node 47: [10, 18, 40, 46, 47, 55]
#     - Representative node 48: [1, 2, 3, 8, 9, 44, 48, 49, 50]
#     - Representative node 52: [0, 7, 21, 22, 51, 52, 57]
#     - Representative node 58: [19, 20, 58]
#     - Representative node 60: [25, 54, 60, 61, 65]
#     - Representative node 62: [35, 37, 53, 62, 63, 64, 66]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4557 rows, 4556 columns and 13534 nonzeros
# Model fingerprint: 0x321c4742
# Variable types: 0 continuous, 4556 integer (4556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve time: 0.04s
# Presolved: 4557 rows, 4556 columns, 13534 nonzeros
# Variable types: 0 continuous, 4556 integer (4556 binary)
# Found heuristic solution: objective 58.0469772
#
# Root relaxation: objective 3.587007e+01, 420 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      35.8700722   35.87007  0.00%     -    0s
#
# Explored 1 nodes (420 simplex iterations) in 0.09 seconds (0.06 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 35.8701 58.047
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.587007222923e+01, best bound 3.587007222923e+01, gap 0.0000%
#
# Optimization Results:
#   - Objective Value: 35.87007222923424
#   - Representatives: [4, 12, 15, 16, 19, 20, 29, 34, 39, 47, 48, 52, 59, 60, 62]
#     - Representative node 4: [4]
#     - Representative node 12: [6, 7, 12, 14, 63]
#     - Representative node 15: [5, 11, 13, 15, 28, 41, 42, 43, 45]
#     - Representative node 16: [16]
#     - Representative node 19: [19, 58]
#     - Representative node 20: [20]
#     - Representative node 29: [23, 24, 26, 27, 29, 30, 38, 44]
#     - Representative node 34: [32, 33, 34, 36]
#     - Representative node 39: [3, 18, 31, 39, 49, 65]
#     - Representative node 47: [10, 40, 46, 47, 55]
#     - Representative node 48: [1, 2, 8, 9, 48, 50]
#     - Representative node 52: [0, 21, 22, 51, 52, 57]
#     - Representative node 59: [17, 56, 59]
#     - Representative node 60: [25, 54, 60, 61]
#     - Representative node 62: [35, 37, 53, 62, 64, 66]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4557 rows, 4556 columns and 13534 nonzeros
# Model fingerprint: 0x2b506ed9
# Variable types: 0 continuous, 4556 integer (4556 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve time: 0.03s
# Presolved: 4557 rows, 4556 columns, 13534 nonzeros
# Variable types: 0 continuous, 4556 integer (4556 binary)
# Found heuristic solution: objective 41.6734610
#
# Root relaxation: objective 2.880907e+01, 367 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      28.8090682   28.80907  0.00%     -    0s
#
# Explored 1 nodes (367 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 28.8091 41.6735
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.880906817835e+01, best bound 2.880906817835e+01, gap 0.0000%
#
# Optimization Results:
#   - Objective Value: 28.809068178351477
#   - Representatives: [2, 4, 5, 13, 14, 16, 18, 20, 29, 31, 34, 41, 47, 50, 52, 55, 58, 59, 60, 62]
#     - Representative node 2: [1, 2, 3, 48]
#     - Representative node 4: [4]
#     - Representative node 5: [5, 6, 15, 43]
#     - Representative node 13: [13, 28]
#     - Representative node 14: [12, 14, 63]
#     - Representative node 16: [16]
#     - Representative node 18: [10, 18, 49]
#     - Representative node 20: [20]
#     - Representative node 29: [23, 26, 27, 29, 30, 38, 44]
#     - Representative node 31: [24, 31, 39, 65]
#     - Representative node 34: [32, 33, 34, 36]
#     - Representative node 41: [11, 41, 42, 45]
#     - Representative node 47: [40, 46, 47]
#     - Representative node 50: [7, 8, 9, 50]
#     - Representative node 52: [0, 21, 22, 51, 52, 57]
#     - Representative node 55: [55]
#     - Representative node 58: [19, 58]
#     - Representative node 59: [17, 56, 59]
#     - Representative node 60: [25, 54, 60, 61]
#     - Representative node 62: [35, 37, 53, 62, 64, 66]

# %%
# Metrics to plot
# metrics = ['REEav', 'NRMSEav', 'CEav', 'NRMSERDCav']
metrics = results[0]['optimized_metrics'].keys()
num_metrics = len(metrics)

# Create a DataFrame from results for easier manipulation
data = []
for result in results:
    for metric in metrics:
        data.append({
            'weights': str(result['weights']),
            'n_repr': result['n_repr'],
            'iteration': result['iteration'],
            'metric': metric,
            'optimized_value': result['optimized_metrics'][metric],
            'kmedoids_value': result['kmedoids_metrics'][metric]
        })

df = pd.DataFrame(data)

# Plot for each weight configuration
for weight_config, weight_data in df.groupby('weights'):
    fig, axes = plt.subplots(num_metrics // 2 + num_metrics % 2, 2, figsize=(12, 10))
    axes = axes.flatten()

    for i, metric in enumerate(metrics):
        ax = axes[i]

        # Subset data for the current metric
        metric_data = weight_data[weight_data['metric'] == metric]

        # Group by n_repr
        for n_repr, group in metric_data.groupby('n_repr'):
            # Plot candle chart for KMedoids iterations
            kmedoids_iterations = group['kmedoids_value']
            ax.boxplot(
                kmedoids_iterations,
                positions=[n_repr],
                widths=0.5,
                showfliers=False,
                patch_artist=True,
                boxprops=dict(facecolor='skyblue', color='blue'),
                medianprops=dict(color='darkblue')
            )

            # Plot optimized value as a single point
            optimized_value = group['optimized_value'].iloc[0]
            ax.scatter(n_repr, optimized_value, color='red')

        ax.set_title(metric)
        ax.set_xlabel('n_repr')
        ax.set_ylabel('Metric Value')

        # Add legend inside each subplot
        handles = [
            plt.Line2D([0], [0], color='red', marker='o', linestyle='', label='Optimized'),
            plt.Line2D([0], [0], color='blue', marker='_', linestyle='-', label='KMedoids (Boxplot)')
        ]
        ax.legend(handles=handles, loc='best', fontsize=10, frameon=False)

    fig.suptitle(f"Metrics for Weight Configuration: {weight_config}", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()
